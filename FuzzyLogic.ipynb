# %% [markdown]
# <a href="https://colab.research.google.com/github/Johny85/World-of-Scripts/blob/master/FuzzyLogic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fuzzywuzzy

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

print ("-------------------(Pritimay Mandal,Mandal Pritimay)-------------------")
print ("Simple/Fuzz Ratio:", fuzz.ratio("Pritimay Mandal","Mandal Pritimay"))
print ("Partial Ratio:", fuzz.partial_ratio("Pritimay Mandal","Mandal Pritimay"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Pritimay Mandal","Mandal Pritimay"))
print ("Token Set Ratio:", fuzz.token_set_ratio("Pritimay Mandal","Mandal Pritimay"))
print ("Weighted Ratio:", fuzz.WRatio("Pritimay Mandal","Mandal Pritimay"))
print("\n")
print ("---------------------(P Mandal,Mandal Pritimay)----------------------")
print ("Simple Ratio:", fuzz.ratio("P Mandal","Mandal Pritimay"))
print ("Partial Ratio:", fuzz.partial_ratio("P Mandal","Mandal Pritimay"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("P Mandal","Mandal Pritimay"))
print ("Token Set Ratio:", fuzz.token_set_ratio("P Mandal","Mandal Pritimay"))
print ("Weighted Ratio:", fuzz.WRatio("P Mandal","Mandal Pritimay"))
print("\n")
print ("-------------------(Pritimay Mandal,Mandal)-----------------------")
print ("Simple Ratio:", fuzz.ratio("Pritimay Mandal","Mandal"))
print ("Partial Ratio:", fuzz.partial_ratio("Pritimay Mandal","Mandal"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Pritimay Mandal","Mandal"))
print ("Token Set Ratio:", fuzz.token_set_ratio("Pritimay Mandal","Mandal"))
print ("Weighted Ratio:", fuzz.WRatio("Pritimay Mandal","Mandal"))
print("\n")
print ("--------------------(Pritimay Mandal,P Mandal)---------------------")
print ("Simple Ratio:", fuzz.ratio("Pritimay Mandal","P Mandal"))
print ("Partial Ratio:", fuzz.partial_ratio("Pritimay Mandal","P Mandal"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Pritimay Mandal","P Mandal"))
print ("Token Set Ratio:", fuzz.token_set_ratio("Pritimay Mandal","P Mandal"))
print ("Weighted Ratio:", fuzz.WRatio("Pritimay Mandal","P Mandal"))
print("\n")
print ("----------------------(Pritimay Mandal,Mandal P)---------------------")
print ("Simple Ratio:", fuzz.ratio("Pritimay Mandal","Mandal P"))
print ("Partial Ratio:", fuzz.partial_ratio("Pritimay Mandal","Mandal P"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Pritimay Mandal","Mandal P"))
print ("Token Set Ratio:", fuzz.token_set_ratio("Pritimay Mandal","Mandal P"))
print ("Weighted Ratio:", fuzz.WRatio("Pritimay Mandal","Mandal P"))
print("\n")
print ("---------------------(Mandal Pritimay,P Mandal)----------------------")
print ("Simple Ratio:", fuzz.ratio("Mandal Pritimay","P Mandal"))
print ("Partial Ratio:", fuzz.partial_ratio("Mandal Pritimay","P Mandal"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Mandal Pritimay","P Mandal"))
print ("Token Set Ratio:", fuzz.token_set_ratio("Mandal Pritimay","P Mandal"))
print ("Weighted Ratio:", fuzz.WRatio("Mandal Pritimay","P Mandal"))
print("\n")
print ("---------------------(Mandal Pritimay,Mandal P)----------------------")
print ("Simple Ratio:", fuzz.ratio("Mandal Pritimay","Mandal P"))
print ("Partial Ratio:", fuzz.partial_ratio("Mandal Pritimay","Mandal P"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Mandal Pritimay","Mandal P"))
print ("Token Set Ratio:", fuzz.token_set_ratio("Mandal Pritimay","Mandal P"))
print ("Weighted Ratio:", fuzz.WRatio("Mandal Pritimay","Mandal P"))
print("\n")
print ("----------------------(PRITIMAY MANDAL,pritimay mandal)----------------")
print ("Simple Ratio:", fuzz.ratio("PRITIMAY MANDAL".upper(),"pritimay mandal".upper()))
print ("Partial Ratio:", fuzz.partial_ratio("PRITIMAY MANDAL".upper(),"pritimay mandal".upper()))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("PRITIMAY MANDAL".upper(),"pritimay mandal".upper()))
print ("Token Set Ratio:", fuzz.token_set_ratio("PRITIMAY MANDAL".upper(),"pritimay mandal".upper()))
print ("Weighted Ratio:", fuzz.WRatio("PRITIMAY MANDAL".upper(),"pritimay mandal".upper()))
print("\n")
print ("----------------------(Pritimay Mandal,pritimay mandal)----------------")
print ("Simple Ratio:", fuzz.ratio("Pritimay Mandal".upper(),"pritimay mandal".upper()))
print ("Partial Ratio:", fuzz.partial_ratio("Pritimay Mandal".upper(),"pritimay mandal".upper()))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Pritimay Mandal".upper(),"pritimay mandal".upper()))
print ("Token Set Ratio:", fuzz.token_set_ratio("Pritimay Mandal".upper(),"pritimay mandal".upper()))
print ("Weighted Ratio:", fuzz.WRatio("Pritimay Mandal".upper(),"pritimay mandal".upper()))
print("\n")
print ("----------------------(Pritimay Mandal,PritimayMandal)----------------")
print ("Simple Ratio:", fuzz.ratio("Pritimay Mandal","PritimayMandal"))
print ("Partial Ratio:", fuzz.partial_ratio("Pritimay Mandal","PritimayMandal"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Pritimay Mandal","PritimayMandal"))
print ("Token Set Ratio:", fuzz.token_set_ratio("Pritimay Mandal","PritimayMandal"))
print ("Weighted Ratio:", fuzz.WRatio("Pritimay Mandal","PritimayMandal"))
print("\n")
print ("----------------------(Pritimay Mandal,PMandal)----------------")
print ("Simple Ratio:", fuzz.ratio("Pritimay Mandal","PMandal"))
print ("Partial Ratio:", fuzz.partial_ratio("Pritimay Mandal","PMandal"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Pritimay Mandal","PMandal"))
print ("Token Set Ratio:", fuzz.token_set_ratio("Pritimay Mandal","PMandal"))
print ("Weighted Ratio:", fuzz.WRatio("Pritimay Mandal","PMandal"))
print("\n")
print ("----------------------(P Mandal,Pritimay Mandal)----------------")
print ("Simple Ratio:", fuzz.ratio("P Mandal","Pritimay Mandal"))
print ("Partial Ratio:", fuzz.partial_ratio("P Mandal","Pritimay Mandal"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("P Mandal","Pritimay Mandal"))
print ("Token Set Ratio:", fuzz.token_set_ratio("P Mandal","Pritimay Mandal"))
print ("Weighted Ratio:", fuzz.WRatio("P Mandal","Pritimay Mandal"))
print("\n")
print ("----------------------(A Kumar,Ashok Kumar)----------------")
print ("Simple Ratio:", fuzz.ratio("A Kumar","Ashok Kumar"))
print ("Partial Ratio:", fuzz.partial_ratio("A Kumar","Ashok Kumar"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("A Kumar","Ashok Kumar"))
print ("Token Set Ratio:", fuzz.token_set_ratio("A Kumar","Ashok Kumar"))
print ("Weighted Ratio:", fuzz.WRatio("A Kumar","Ashok Kumar"))
print("\n")
print ("----------------------(A Kumar,Ajay Kumar)----------------")
print ("Simple Ratio:", fuzz.ratio("A Kumar","Ajay Kumar"))
print ("Partial Ratio:", fuzz.partial_ratio("A Kumar","Ajay Kumar"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("A Kumar","Ajay Kumar"))
print ("Token Set Ratio:", fuzz.token_set_ratio("A Kumar","Ajay Kumar"))
print ("Weighted Ratio:", fuzz.WRatio("A Kumar","Ajay Kumar"))
print("\n")
print ("----------------------(A Kumar,Amit Kumar)----------------")
print ("Simple Ratio:", fuzz.ratio("A Kumar","Amit Kumar"))
print ("Partial Ratio:", fuzz.partial_ratio("A Kumar","Amit Kumar"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("A Kumar","Amit Kumar"))
print ("Token Set Ratio:", fuzz.token_set_ratio("A Kumar","Amit Kumar"))
print ("Weighted Ratio:", fuzz.WRatio("A Kumar","Amit Kumar"))
print("\n")
print ("----------------------(A.Kumar,Amit Kumar)----------------")
print ("Simple Ratio:", fuzz.ratio("A.Kumar","Amit Kumar"))
print ("Partial Ratio:", fuzz.partial_ratio("A.Kumar","Amit Kumar"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("A.Kumar","Amit Kumar"))
print ("Token Set Ratio:", fuzz.token_set_ratio("A.Kumar","Amit Kumar"))
print ("Weighted Ratio:", fuzz.WRatio("A.Kumar","Amit Kumar"))
print("\n")
print ("----------------------(Abhishek Kumar,Abhish Kumar)----------------")
print ("Simple Ratio:", fuzz.ratio("Abhishek Kumar","Abhish Kumar"))
print ("Partial Ratio:", fuzz.partial_ratio("Abhishek Kumar","Abhish Kumar"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Abhishek Kumar","Abhish Kumar"))
print ("Token Set Ratio:", fuzz.token_set_ratio("Abhishek Kumar","Abhish Kumar"))
print ("Weighted Ratio:", fuzz.WRatio("Abhishek Kumar","Abhish Kumar"))
print("\n")
print ("----------------------(Paramjit Singh,Paramjeet Singh)----------------")
print ("Simple Ratio:", fuzz.ratio("Paramjit Singh","Paramjeet Singh"))
print ("Partial Ratio:", fuzz.partial_ratio("Paramjit Singh","Paramjeet Singh"))
print ("Token Sort Ratio:", fuzz.token_sort_ratio("Paramjit Singh","Paramjeet Singh"))
print ("Token Set Ratio:", fuzz.token_set_ratio("Paramjit Singh","Paramjeet Singh"))
print ("Weighted Ratio:", fuzz.WRatio("Paramjit Singh","Paramjeet Singh"))
print("\n")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# -------------------(Pritimay Mandal,Mandal Pritimay)-------------------
# Simple/Fuzz Ratio: 53
# Partial Ratio: 70
# Token Sort Ratio: 100
# Token Set Ratio: 100
# Weighted Ratio: 95
#
#
# ---------------------(P Mandal,Mandal Pritimay)----------------------
# Simple Ratio: 52
# Partial Ratio: 75
# Token Sort Ratio: 70
# Token Set Ratio: 86
# Weighted Ratio: 86
#
#
# -------------------(Pritimay Mandal,Mandal)-----------------------
# Simple Ratio: 57
# Partial Ratio: 100
# Token Sort Ratio: 57
# Token Set Ratio: 100
# Weighted Ratio: 90
#
#
# --------------------(Pritimay Mandal,P Mandal)---------------------
# Simple Ratio: 70
# Partial Ratio: 88
# Token Sort Ratio: 70
# Token Set Ratio: 86
# Weighted Ratio: 86
#
#
# ----------------------(Pritimay Mandal,Mandal P)---------------------
# Simple Ratio: 52
# Partial Ratio: 86
# Token Sort Ratio: 70
# Token Set Ratio: 86
# ...
